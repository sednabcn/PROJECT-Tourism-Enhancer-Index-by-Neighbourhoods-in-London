# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np # library to handle data in a vectorized manner
 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
# !pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.3.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/lib/python3/dist-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.17.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from branca>=0.3.0->folium) (1.12.0)
# Libraries imported.

# %% [markdown]
# International visitors London File csv
#
# visitors-london-country-year

# %%
boroughs=pd.read_csv("/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/DATA/Boroughs_london.csv",index_col=0)

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the boroughs and segment them.
#
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'X3INNHZFS0RE4YAMNP5CCG4UVUP4S5K1S4NZIIXKHN2UNXJW' # your Foursquare ID
CLIENT_SECRET = '20EOF0IP0MALLD0RO0MM1QOCLEHXC35L4U3JHMETTEF24YJR' # your Foursquare Secret

VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: X3INNHZFS0RE4YAMNP5CCG4UVUP4S5K1S4NZIIXKHN2UNXJW
# CLIENT_SECRET:20EOF0IP0MALLD0RO0MM1QOCLEHXC35L4U3JHMETTEF24YJR

# %% [markdown]
# Explore boroughs in London.
# Let's create a function to repeat the same process to all the boroughs in London

# %%
London_boroughs_venues=pd.read_csv("/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/DATA/london_boroughs_venues.csv", index_col=0)

# %% [markdown]
# Let's check how many venues were returned for each borough

# %%
London_boroughs_venues.groupby('Borough').count()
# Out:
#                         Latitude  Longitude  Venue  Venue Latitude  \
# Borough
# Barking and Dagenham           7          7      7               7
# Barnet                         3          3      3               3
# Bexley                        28         28     28              28
# Brent                         71         71     71              71
# Bromley                       42         42     42              42
# Camden                       100        100    100             100
# City of London               100        100    100             100
# Croydon                       40         40     40              40
# Ealing                        72         72     72              72
# Enfield                       58         58     58              58
# Greenwich                     40         40     40              40
# Hackney                       61         61     61              61
# Hammersmith and Fulham        78         78     78              78
# Haringey                      20         20     20              20
# Harrow                         6          6      6               6
# Havering                      38         38     38              38
# Hillingdon                    63         63     63              63
# Hounslow                       4          4      4               4
# Islington                     68         68     68              68
# Kensington and Chelsea        67         67     67              67
# Kingston upon Thames         100        100    100             100
# Lambeth                      100        100    100             100
# Lewisham                      32         32     32              32
# Merton                        18         18     18              18
# Newham                        14         14     14              14
# Redbridge                     41         41     41              41
# Richmond upon Thames          55         55     55              55
# Southwark                    100        100    100             100
# Sutton                        36         36     36              36
# Tower Hamlets                 17         17     17              17
# Waltham Forest                14         14     14              14
# Wandsworth                    40         40     40              40
# Westminster                   78         78     78              78
#
#                         Venue Longitude  Venue category  Venue Category
# Borough
# Barking and Dagenham                  7               7               7
# Barnet                                3               3               3
# Bexley                               28              28              28
# Brent                                71              71              71
# Bromley                              42              42              42
# Camden                              100             100             100
# City of London                      100             100             100
# Croydon                              40              40              40
# Ealing                               72              72              72
# Enfield                              58              58              58
# Greenwich                            40              40              40
# Hackney                              61              61              61
# Hammersmith and Fulham               78              78              78
# Haringey                             20              20              20
# Harrow                                6               6               6
# Havering                             38              38              38
# Hillingdon                           63              63              63
# Hounslow                              4               4               4
# Islington                            68              68              68
# Kensington and Chelsea               67              67              67
# Kingston upon Thames                100             100             100
# Lambeth                             100             100             100
# Lewisham                             32              32              32
# Merton                               18              18              18
# Newham                               14              14              14
# Redbridge                            41              41              41
# Richmond upon Thames                 55              55              55
# Southwark                           100             100             100
# Sutton                               36              36              36
# Tower Hamlets                        17              17              17
# Waltham Forest                       14              14              14
# Wandsworth                           40              40              40
# Westminster                          78              78              78

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(London_boroughs_venues['Venue Category'].unique())))
# Out:
# There are 7 uniques categories.

# %%
print(London_boroughs_venues['Venue Category'].unique())
# Out:
# ['food' 'shops' 'travel' 'nightlife' 'arts_entertainment' 'parks_outdoors'
#  'building']

# %% [markdown]
# Analize each borough

# %%
# one hot encoding
London_boroughs_onehot = pd.get_dummies(London_boroughs_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
London_boroughs_onehot['Borough'] = London_boroughs_venues['Borough'] 

# move neighborhood column to the first column
fixed_columns = [London_boroughs_onehot.columns[-1]] + list(London_boroughs_onehot.columns[:-1])
London_boroughs_onehot = London_boroughs_onehot[fixed_columns]

London_boroughs_onehot.head()
# Out:
#           Borough  arts_entertainment  building  food  nightlife  \
# 0  City of London                   0         0     1          0
# 1  City of London                   0         0     1          0
# 2  City of London                   0         0     0          0
# 3  City of London                   0         0     1          0
# 4  City of London                   0         0     0          0
#
#    parks_outdoors  shops  travel
# 0               0      0       0
# 1               0      0       0
# 2               0      1       0
# 3               0      0       0
# 4               0      0       1

# %% [markdown]
# Examine the dataframe size

# %%
London_boroughs_onehot.shape
# Out:
# (1611, 8)

# %% [markdown]
# Next, let's group rows by borough and by taking the mean of the frequency of occurrence of each category

# %%
heat_map_b05=London_boroughs_onehot.groupby('Borough').sum().reset_index()
heat_map_b05.to_excel('/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/RESULTS/heat_map_b05.xlsx')

# %%
London_boroughs_grouped = London_boroughs_onehot.groupby('Borough').mean().reset_index()
London_boroughs_grouped
# Out:
#                    Borough  arts_entertainment  building      food  nightlife  \
# 0     Barking and Dagenham            0.000000  0.142857  0.000000   0.000000
# 1                   Barnet            0.000000  0.000000  0.666667   0.000000
# 2                   Bexley            0.035714  0.035714  0.392857   0.107143
# 3                    Brent            0.042254  0.014085  0.436620   0.084507
# 4                  Bromley            0.000000  0.071429  0.500000   0.095238
# 5                   Camden            0.050000  0.020000  0.520000   0.110000
# 6           City of London            0.090000  0.060000  0.590000   0.050000
# 7                  Croydon            0.000000  0.050000  0.550000   0.150000
# 8                   Ealing            0.041667  0.027778  0.569444   0.097222
# 9                  Enfield            0.017241  0.051724  0.327586   0.068966
# 10               Greenwich            0.000000  0.000000  0.450000   0.075000
# 11                 Hackney            0.032787  0.032787  0.442623   0.147541
# 12  Hammersmith and Fulham            0.012821  0.000000  0.538462   0.153846
# 13                Haringey            0.050000  0.050000  0.450000   0.150000
# 14                  Harrow            0.166667  0.000000  0.333333   0.000000
# 15                Havering            0.026316  0.026316  0.289474   0.078947
# 16              Hillingdon            0.015873  0.031746  0.460317   0.047619
# 17                Hounslow            0.000000  0.000000  0.500000   0.000000
# 18               Islington            0.088235  0.014706  0.470588   0.205882
# 19  Kensington and Chelsea            0.089552  0.059701  0.567164   0.029851
# 20    Kingston upon Thames            0.020000  0.010000  0.560000   0.080000
# 21                 Lambeth            0.050000  0.030000  0.620000   0.130000
# 22                Lewisham            0.031250  0.000000  0.375000   0.093750
# 23                  Merton            0.000000  0.000000  0.611111   0.055556
# 24                  Newham            0.000000  0.000000  0.214286   0.071429
# 25               Redbridge            0.048780  0.024390  0.414634   0.048780
# 26    Richmond upon Thames            0.018182  0.036364  0.527273   0.163636
# 27               Southwark            0.070000  0.020000  0.540000   0.150000
# 28                  Sutton            0.000000  0.027778  0.416667   0.222222
# 29           Tower Hamlets            0.000000  0.117647  0.647059   0.000000
# 30          Waltham Forest            0.142857  0.071429  0.357143   0.214286
# 31              Wandsworth            0.025000  0.050000  0.450000   0.100000
# 32             Westminster            0.089744  0.051282  0.576923   0.038462
#
#     parks_outdoors     shops    travel
# 0         0.428571  0.285714  0.142857
# 1         0.000000  0.000000  0.333333
# 2         0.035714  0.357143  0.035714
# 3         0.042254  0.253521  0.126761
# 4         0.000000  0.333333  0.000000
# 5         0.040000  0.140000  0.120000
# 6         0.080000  0.080000  0.050000
# 7         0.025000  0.150000  0.075000
# 8         0.041667  0.166667  0.055556
# 9         0.000000  0.500000  0.034483
# 10        0.050000  0.325000  0.100000
# 11        0.016393  0.262295  0.065574
# 12        0.038462  0.153846  0.102564
# 13        0.050000  0.150000  0.100000
# 14        0.000000  0.333333  0.166667
# 15        0.026316  0.473684  0.078947
# 16        0.000000  0.412698  0.031746
# 17        0.250000  0.000000  0.250000
# 18        0.044118  0.176471  0.000000
# 19        0.029851  0.164179  0.059701
# 20        0.020000  0.290000  0.020000
# 21        0.010000  0.150000  0.010000
# 22        0.000000  0.343750  0.156250
# 23        0.166667  0.166667  0.000000
# 24        0.071429  0.071429  0.571429
# 25        0.000000  0.341463  0.121951
# 26        0.018182  0.181818  0.054545
# 27        0.090000  0.070000  0.060000
# 28        0.027778  0.277778  0.027778
# 29        0.000000  0.117647  0.117647
# 30        0.214286  0.000000  0.000000
# 31        0.000000  0.350000  0.025000
# 32        0.025641  0.089744  0.128205

# %%
London_boroughs_grouped.to_excel('/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/RESULTS/London_boroughs_grouped.xlsx')

# %% [markdown]
# Let's confirm new size

# %%
London_boroughs_grouped.shape
# Out:
# (33, 8)

# %% [markdown]
# Let's print each borough with the 3 most common venues

# %%
num_top_venues = 3

for hood in London_boroughs_grouped['Borough']:
    print("----"+hood+"----")
    temp = London_boroughs_grouped[London_boroughs_grouped['Borough'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Barking and Dagenham----
#             venue  freq
# 0  parks_outdoors  0.43
# 1           shops  0.29
# 2        building  0.14
#
#
# ----Barnet----
#                 venue  freq
# 0                food  0.67
# 1              travel  0.33
# 2  arts_entertainment  0.00
#
#
# ----Bexley----
#        venue  freq
# 0       food  0.39
# 1      shops  0.36
# 2  nightlife  0.11
#
#
# ----Brent----
#     venue  freq
# 0    food  0.44
# 1   shops  0.25
# 2  travel  0.13
#
#
# ----Bromley----
#        venue  freq
# 0       food  0.50
# 1      shops  0.33
# 2  nightlife  0.10
#
#
# ----Camden----
#     venue  freq
# 0    food  0.52
# 1   shops  0.14
# 2  travel  0.12
#
#
# ----City of London----
#                 venue  freq
# 0                food  0.59
# 1  arts_entertainment  0.09
# 2      parks_outdoors  0.08
#
#
# ----Croydon----
#        venue  freq
# 0       food  0.55
# 1  nightlife  0.15
# 2      shops  0.15
#
#
# ----Ealing----
#        venue  freq
# 0       food  0.57
# 1      shops  0.17
# 2  nightlife  0.10
#
#
# ----Enfield----
#        venue  freq
# 0      shops  0.50
# 1       food  0.33
# 2  nightlife  0.07
#
#
# ----Greenwich----
#     venue  freq
# 0    food  0.45
# 1   shops  0.32
# 2  travel  0.10
#
#
# ----Hackney----
#        venue  freq
# 0       food  0.44
# 1      shops  0.26
# 2  nightlife  0.15
#
#
# ----Hammersmith and Fulham----
#        venue  freq
# 0       food  0.54
# 1  nightlife  0.15
# 2      shops  0.15
#
#
# ----Haringey----
#        venue  freq
# 0       food  0.45
# 1  nightlife  0.15
# 2      shops  0.15
#
#
# ----Harrow----
#                 venue  freq
# 0                food  0.33
# 1               shops  0.33
# 2  arts_entertainment  0.17
#
#
# ----Havering----
#        venue  freq
# 0      shops  0.47
# 1       food  0.29
# 2  nightlife  0.08
#
#
# ----Hillingdon----
#        venue  freq
# 0       food  0.46
# 1      shops  0.41
# 2  nightlife  0.05
#
#
# ----Hounslow----
#             venue  freq
# 0            food  0.50
# 1  parks_outdoors  0.25
# 2          travel  0.25
#
#
# ----Islington----
#        venue  freq
# 0       food  0.47
# 1  nightlife  0.21
# 2      shops  0.18
#
#
# ----Kensington and Chelsea----
#                 venue  freq
# 0                food  0.57
# 1               shops  0.16
# 2  arts_entertainment  0.09
#
#
# ----Kingston upon Thames----
#        venue  freq
# 0       food  0.56
# 1      shops  0.29
# 2  nightlife  0.08
#
#
# ----Lambeth----
#        venue  freq
# 0       food  0.62
# 1      shops  0.15
# 2  nightlife  0.13
#
#
# ----Lewisham----
#     venue  freq
# 0    food  0.38
# 1   shops  0.34
# 2  travel  0.16
#
#
# ----Merton----
#             venue  freq
# 0            food  0.61
# 1  parks_outdoors  0.17
# 2           shops  0.17
#
#
# ----Newham----
#        venue  freq
# 0     travel  0.57
# 1       food  0.21
# 2  nightlife  0.07
#
#
# ----Redbridge----
#     venue  freq
# 0    food  0.41
# 1   shops  0.34
# 2  travel  0.12
#
#
# ----Richmond upon Thames----
#        venue  freq
# 0       food  0.53
# 1      shops  0.18
# 2  nightlife  0.16
#
#
# ----Southwark----
#             venue  freq
# 0            food  0.54
# 1       nightlife  0.15
# 2  parks_outdoors  0.09
#
#
# ----Sutton----
#        venue  freq
# 0       food  0.42
# 1      shops  0.28
# 2  nightlife  0.22
#
#
# ----Tower Hamlets----
#       venue  freq
# 0      food  0.65
# 1  building  0.12
# 2     shops  0.12
#
#
# ----Waltham Forest----
#             venue  freq
# 0            food  0.36
# 1       nightlife  0.21
# 2  parks_outdoors  0.21
#
#
# ----Wandsworth----
#        venue  freq
# 0       food  0.45
# 1      shops  0.35
# 2  nightlife  0.10
#
#
# ----Westminster----
#                 venue  freq
# 0                food  0.58
# 1              travel  0.13
# 2  arts_entertainment  0.09

# %% [markdown]
# Let's put that into a pandas dataframe. First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 3 venues for each borough.

# %%
num_top_venues = 3

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Borough']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
boroughs_venues_sorted = pd.DataFrame(columns=columns)
boroughs_venues_sorted['Borough'] = London_boroughs_grouped['Borough']

for ind in np.arange(London_boroughs_grouped.shape[0]):
    boroughs_venues_sorted.iloc[ind, 1:] = return_most_common_venues(London_boroughs_grouped.iloc[ind, :], num_top_venues)

boroughs_venues_sorted.head()
# Out:
#                 Borough 1st Most Common Venue 2nd Most Common Venue  \
# 0  Barking and Dagenham        parks_outdoors                 shops
# 1                Barnet                  food                travel
# 2                Bexley                  food                 shops
# 3                 Brent                  food                 shops
# 4               Bromley                  food                 shops
#
#   3rd Most Common Venue
# 0                travel
# 1                 shops
# 2             nightlife
# 3                travel
# 4             nightlife

# %%
London_boroughs_grouped_clustering = London_boroughs_grouped.drop('Borough', 1)

# %% [markdown]
# SSD=norm2(samples,nearest_clusters_centre) Elbow curve to determine the optimal number of clusters

# %%
SSD = []
K = range(1,20)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(London_boroughs_grouped_clustering)
    SSD.append(km.inertia_)

# %% [markdown]
# ELBOW CURVE FOR KMEANS

# %%
import matplotlib.pyplot as plt
def elbow(norm):
    plt.plot(K,norm, 'ro-')
    plt.xlabel('k')
    plt.ylabel('L2-norm')
    plt.title('Elbow Method For Optimal k')
    return plt.show()

# %%
elbow_curve=elbow(SSD)
elbow_b05=np.empty([19,2])
elbow_b05=pd.DataFrame(elbow_b05,columns=['K','SSD'])
elbow_b05['K']=K
elbow_b05['SSD']=SSD
elbow_b05.to_excel('/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/RESULTS/elbow_b05.xlsx')

# %%
elbow_b05
# Out:
#      K       SSD
# 0    1  2.032199
# 1    2  1.413778
# 2    3  1.069566
# 3    4  0.726876
# 4    5  0.575184
# 5    6  0.466547
# 6    7  0.394000
# 7    8  0.333310
# 8    9  0.277839
# 9   10  0.224801
# 10  11  0.193955
# 11  12  0.166011
# 12  13  0.147540
# 13  14  0.125599
# 14  15  0.106364
# 15  16  0.094374
# 16  17  0.086915
# 17  18  0.070197
# 18  19  0.061294

# %%
np.min(np.array(SSD))
# Out:
# 0.06129440739933095

# %% [markdown]
# Cluster Boroughs. Run k-means to cluster the boroughs into 10 clusters.

# %%
boroughs_venues_sorted.shape
# Out:
# (33, 4)

# %%
# set number of clusters
kclusters = 3


# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(London_boroughs_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
kmeans_labels=kmeans.labels_

# %%
from sklearn import metrics
from sklearn.metrics import pairwise_distances
s_score=metrics.silhouette_score(London_boroughs_grouped_clustering,kmeans_labels, metric='euclidean')
s_score=pd.Series(s_score,index=[kclusters])

# %%
pp=pd.DataFrame(kmeans.labels_,columns=['Cluster Labels'])
Kclusters_b03=pp['Cluster Labels'].value_counts().sort_index()
Kclusters_b03=Kclusters_b03.append(s_score)
Kclusters_b03
# Out:
# 0    18.000000
# 1     1.000000
# 2    14.000000
# 3     0.317699
# dtype: float64

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each borough.

# %%
# add clustering labels
boroughs_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
# merge London_borough_grouped with to add latitude/longitude for each borough
London_boroughs_merged =pd.merge(boroughs,boroughs_venues_sorted, on='Borough').sort_values('Cluster Labels')

London_boroughs_merged.head() # check the last columns!
# Out:
#          Code               Borough   Inner/Outer  GLA_P2017  GLA_H2017  \
# 0   E09000001        City of London  Inner London       8800       5326
# 30  E09000031        Waltham Forest  Outer London     276200     105981
# 29  E09000030         Tower Hamlets  Inner London     304000     123720
# 27  E09000028             Southwark  Inner London     314300     134254
# 26  E09000027  Richmond upon Thames  Outer London     197300      85108
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0    51.5155    -0.0922               0                  food
# 30   51.5908    -0.0134               0                  food
# 29   51.5099    -0.0059               0                  food
# 27   51.5035    -0.0804               0                  food
# 26   51.4479    -0.3260               0                  food
#
#    2nd Most Common Venue 3rd Most Common Venue
# 0     arts_entertainment                 shops
# 30        parks_outdoors             nightlife
# 29                travel                 shops
# 27             nightlife        parks_outdoors
# 26                 shops             nightlife

# %%
address = 'London,UK'

geolocator = Nominatim(user_agent="to_explorer",timeout=50)
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_boroughs_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**3 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(London_boroughs_merged['Latitude'], London_boroughs_merged['Longitude'],
                                  London_boroughs_merged['Borough'], London_boroughs_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.3).add_to(map_boroughs_clusters)
       
map_boroughs_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#map_boroughs_clusters.save("/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/RESULTS/map_London_boroughs_clusters_Category03.html")

# %% [markdown]
# Examine Clusters. Now, I can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, I will assign a name to each cluster.

# %%
    print ('CLuster 1: ')
# Out:
# CLuster 1:

# %%
 London_boroughs_merged.loc[London_boroughs_merged['Cluster Labels']==0,:]
# Out:
#          Code                 Borough   Inner/Outer  GLA_P2017  GLA_H2017  \
# 0   E09000001          City of London  Inner London       8800       5326
# 30  E09000031          Waltham Forest  Outer London     276200     105981
# 29  E09000030           Tower Hamlets  Inner London     304000     123720
# 27  E09000028               Southwark  Inner London     314300     134254
# 26  E09000027    Richmond upon Thames  Outer London     197300      85108
# 24  E09000025                  Newham  Inner London     342900     119172
# 23  E09000024                  Merton  Outer London     208100      84201
# 21  E09000022                 Lambeth  Inner London     328900     144400
# 19  E09000020  Kensington and Chelsea  Inner London     159000      80200
# 18  E09000019               Islington  Inner London     231200     105038
# 17  E09000018                Hounslow  Outer London     274200     105887
# 13  E09000014                Haringey  Inner London     278000     115608
# 32  E09000033             Westminster  Inner London     242100     118975
# 2   E09000003                  Barnet  Outer London     389600     151423
# 8   E09000009                  Ealing  Outer London     351600     132663
# 7   E09000008                 Croydon  Outer London     386500     159010
# 12  E09000013  Hammersmith and Fulham  Inner London     185300      83552
# 6   E09000007                  Camden  Inner London     242500     107654
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0    51.5155    -0.0922               0                  food
# 30   51.5908    -0.0134               0                  food
# 29   51.5099    -0.0059               0                  food
# 27   51.5035    -0.0804               0                  food
# 26   51.4479    -0.3260               0                  food
# 24   51.5077     0.0469               0                travel
# 23   51.4014    -0.1958               0                  food
# 21   51.4607    -0.1163               0                  food
# 19   51.5020    -0.1947               0                  food
# 18   51.5416    -0.1022               0                  food
# 17   51.4746    -0.3680               0                  food
# 13   51.6000    -0.1119               0                  food
# 32   51.4973    -0.1372               0                  food
# 2    51.6252    -0.1517               0                  food
# 8    51.5130    -0.3089               0                  food
# 7    51.3714    -0.0977               0                  food
# 12   51.4927    -0.2339               0                  food
# 6    51.5290    -0.1255               0                  food
#
#    2nd Most Common Venue 3rd Most Common Venue
# 0     arts_entertainment                 shops
# 30        parks_outdoors             nightlife
# 29                travel                 shops
# 27             nightlife        parks_outdoors
# 26                 shops             nightlife
# 24                  food                 shops
# 23                 shops        parks_outdoors
# 21                 shops             nightlife
# 19                 shops    arts_entertainment
# 18             nightlife                 shops
# 17                travel        parks_outdoors
# 13                 shops             nightlife
# 32                travel                 shops
# 2                 travel                 shops
# 8                  shops             nightlife
# 7                  shops             nightlife
# 12                 shops             nightlife
# 6                  shops                travel

# %%
 print ('CLuster 2: ')
# Out:
# CLuster 2:

# %%
London_boroughs_merged.loc[London_boroughs_merged['Cluster Labels']==1,:]
# Out:
#         Code               Borough   Inner/Outer  GLA_P2017  GLA_H2017  \
# 1  E09000002  Barking and Dagenham  Outer London     209000      78188
#
#    Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 1   51.5607     0.1557               1        parks_outdoors
#
#   2nd Most Common Venue 3rd Most Common Venue
# 1                 shops                travel

# %%
print ('Cluster 3: ')
# Out:
# Cluster 3:

# %%
London_boroughs_merged.loc[London_boroughs_merged['Cluster Labels']==2,:]
# Out:
#          Code               Borough   Inner/Outer  GLA_P2017  GLA_H2017  \
# 11  E09000012               Hackney  Inner London     274300     115417
# 28  E09000029                Sutton  Outer London     202600      85243
# 3   E09000004                Bexley  Outer London     244300      97736
# 4   E09000005                 Brent  Outer London     332100     121048
# 25  E09000026             Redbridge  Outer London     304200     110708
# 22  E09000023              Lewisham  Inner London     303400     131076
# 20  E09000021  Kingston upon Thames  Outer London     175400      69849
# 9   E09000010               Enfield  Outer London     333000     130328
# 10  E09000011             Greenwich  Outer London     280100     113964
# 31  E09000032            Wandsworth  Inner London     321000     138149
# 15  E09000016              Havering  Outer London     254300     104098
# 14  E09000015                Harrow  Outer London     252300      92557
# 5   E09000006               Bromley  Outer London     327900     140602
# 16  E09000017            Hillingdon  Outer London     301000     110827
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 11   51.5450    -0.0553               2                  food
# 28   51.3618    -0.1945               2                  food
# 3    51.4549     0.1505               2                  food
# 4    51.5588    -0.2817               2                  food
# 25   51.5590     0.0741               2                  food
# 22   51.4452    -0.0209               2                  food
# 20   51.4085    -0.3064               2                  food
# 9    51.6538    -0.0799               2                 shops
# 10   51.4892     0.0648               2                  food
# 31   51.4567    -0.1910               2                  food
# 15   51.5812     0.1837               2                 shops
# 14   51.5898    -0.3346               2                 shops
# 5    51.4039     0.0198               2                  food
# 16   51.5441    -0.4760               2                  food
#
#    2nd Most Common Venue 3rd Most Common Venue
# 11                 shops             nightlife
# 28                 shops             nightlife
# 3                  shops             nightlife
# 4                  shops                travel
# 25                 shops                travel
# 22                 shops                travel
# 20                 shops             nightlife
# 9                   food             nightlife
# 10                 shops                travel
# 31                 shops             nightlife
# 15                  food                travel
# 14                  food                travel
# 5                  shops             nightlife
# 16                 shops             nightlife

# %%
Borough_Cluster_03={}
for ii in range(kclusters):
    Borough_Cluster_03[ii]=[London_boroughs_merged.loc[London_boroughs_merged['Cluster Labels']==ii,:]['Borough'].values.tolist()]

# %%
Borough_Cluster_03=pd.DataFrame.from_dict(Borough_Cluster_03)
Borough_Cluster_03.to_csv('/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/DATA/Borough_Cluster_03.csv')

# %%
Borough_Cluster_03[0][0]
# Out:
# ['City of London',
#  'Waltham Forest',
#  'Tower Hamlets',
#  'Southwark',
#  'Richmond upon Thames',
#  'Newham',
#  'Merton',
#  'Lambeth',
#  'Kensington and Chelsea',
#  'Islington',
#  'Hounslow',
#  'Haringey',
#  'Westminster',
#  'Barnet',
#  'Ealing',
#  'Croydon',
#  'Hammersmith and Fulham',
#  'Camden']

# %%
x=[]
y=[]
for ii in range(kclusters):
    x.append(London_boroughs_merged.loc[London_boroughs_merged['Cluster Labels']==ii,:]['Latitude'].mean())
    y.append(London_boroughs_merged.loc[London_boroughs_merged['Cluster Labels']==ii,:]['Longitude'].mean())
Centroids_b03=np.empty([kclusters,2])                                         
Centroids_b03=pd.DataFrame(Centroids_b03, columns=['x-Latitude','y-Longitude']) 
Centroids_b03['x-Latitude']=x
Centroids_b03['y-Longitude']=y
Centroids_b03.to_excel('/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/RESULTS/Centroids_b03.xlsx')

# %%
Centroids_b03
# Out:
#    x-Latitude  y-Longitude
# 0   51.504678    -0.145267
# 1   51.560700     0.155700
# 2   51.503707    -0.103386

# %%
features=London_boroughs_grouped_clustering.columns.tolist()
# clustering purity 
score=pd.DataFrame(index=features,columns=range(kclusters))

for ii in range(kclusters):
           pp=London_boroughs_merged.loc[London_boroughs_merged['Cluster Labels']==ii,:].\
                        groupby("1st Most Common Venue").count()['Borough']
           for nn in range(len(features)):
                try: 
                    score.loc[features[nn],ii]=pp.loc[features[nn]]
                except:
                    score.loc[features[nn],ii]=0
score
# Out:
#                      0  1   2
# arts_entertainment   0  0   0
# building             0  0   0
# food                17  0  11
# nightlife            0  0   0
# parks_outdoors       0  1   0
# shops                0  0   3
# travel               1  0   0

# %%
p_score=score.max().sum()/score.sum().sum()
p_score=pd.Series(p_score,index=[kclusters+1])
Kclusters_b03=Kclusters_b03.append(p_score)

# %%
Kclusters_b03.to_excel('/home/sedna/Downloads/PROJECT-COURSERA-CAPSTONE/RESULTS/Kclusters_b03.xlsx')
Kclusters_b03
# Out:
# 0    18.000000
# 1     1.000000
# 2    14.000000
# 3     0.317699
# 4     0.878788
# dtype: float64
